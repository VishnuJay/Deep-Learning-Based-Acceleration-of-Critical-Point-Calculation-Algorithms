# %%
import KeyFunctions as me
import shutil
import pandas as pd

Dataset = "Ghorayeb-13"
EOS = "PR"

# %%
ydf, Cpdf = me.CreateBasisTrain(0, Dataset, EOS, 150)
fname = 'MX_'+str(1)+'_Train.csv'
df = pd.concat([ydf, Cpdf], axis = 1)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
pd.set_option('display.max_rows', 500)
dfN = df.dropna(axis = 0)
dfN
# Out:
#           CO2       CH4        C2        C3        C4        C5        C6  \
# 0    0.000043  0.036748  0.031073  0.095089  0.035237  0.165001  0.036747
# 1    0.000887  0.064930  0.001167  0.099074  0.022786  0.158508  0.349282
# 2    0.001341  0.010877  0.024890  0.239369  0.020545  0.012478  0.019968
# 3    0.001930  0.205390  0.020153  0.219498  0.044953  0.105463  0.003754
# 4    0.002098  0.054263  0.014683  0.018842  0.011243  0.037963  0.018124
# 5    0.002709  0.030778  0.027833  0.014425  0.109810  0.146482  0.009554
# 6    0.003466  0.171995  0.039548  0.007066  0.113428  0.180718  0.074965
# 7    0.003548  0.026141  0.057493  0.042399  0.223340  0.005534  0.135119
# 8    0.003636  0.107377  0.014966  0.217665  0.001173  0.035948  0.142365
# 9    0.004756  0.013604  0.257118  0.040704  0.110915  0.000130  0.102053
# 10   0.005272  0.070243  0.048057  0.087375  0.009943  0.074276  0.120437
# 11   0.005615  0.007163  0.008028  0.053832  0.174898  0.022248  0.003743
# ...

# %%
df.to_csv(fname , mode = 'w')
